# %% [markdown]
# <a href="https://colab.research.google.com/github/franchesco117/curso/blob/master/Pandas_Exercise_for_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Import pandas as pd and load the dataset

# %%
# Use this line to load the dataset.
url='https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
# your code here


import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Puedes realizar operaciones o análisis de datos con el conjunto de datos cargado aquí.

# %% [markdown]
# Basic Exploration
#
# Let's first take a quick look at what this data looks like.

# %%
# for basic exploration, we suggest to use shape, head(), tail(), dtypes, type() modules
# your code here
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Obtener la forma del conjunto de datos
print("Shape:")
print(dataset.shape)
print()

# Mostrar las primeras filas del conjunto de datos
print("Head:")
print(dataset.head())
print()

# Mostrar las últimas filas del conjunto de datos
print("Tail:")
print(dataset.tail())
print()

# Obtener los tipos de datos de cada columna
print("Data Types:")
print(dataset.dtypes)
print()

# Obtener el tipo del objeto del conjunto de datos
print("Type:")
print(type(dataset))
# Out:
# Shape:
# (1145586, 5)
#
# Head:
#    station_id       stationname        date daytype  rides
# 0       41280    Jefferson Park  12/22/2017       W   6104
# 1       41000  Cermak-Chinatown  12/18/2017       W   3636
# 2       40280      Central-Lake  12/02/2017       A   1270
# 3       40140   Dempster-Skokie  12/19/2017       W   1759
# 4       40690          Dempster  12/03/2017       U    499
#
# Tail:
#          station_id        stationname        date daytype  rides
# 1145581       41700  Washington/Wabash  12/27/2022       W   3991
# 1145582       41700  Washington/Wabash  12/28/2022       W   4100
# 1145583       41700  Washington/Wabash  12/29/2022       W   4741
# 1145584       41700  Washington/Wabash  12/30/2022       W   4664
# 1145585       41700  Washington/Wabash  12/31/2022       A   2774
#
# Data Types:
# station_id      int64
# stationname    object
# date           object
# daytype        object
# rides           int64
# dtype: object
#
# Type:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# What are some basic statistics about the data?

# %%
# use the describe module
# your code here
pass

import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Utilizar el método describe() en el conjunto de datos
description = dataset.describe()
print(description)
# Out:
#          station_id         rides
# count  1.145586e+06  1.145586e+06
# mean   4.076649e+04  3.056635e+03
# std    4.490665e+02  3.118576e+03
# min    4.001000e+04  0.000000e+00
# 25%    4.037000e+04  9.630000e+02
# 50%    4.076000e+04  2.004000e+03
# 75%    4.115000e+04  4.025000e+03
# max    4.170000e+04  3.632300e+04

# %% [markdown]
# Selection Based on Conditionals
#
# Let's see which stations have the most and fewest rides.

# %%
# use the min() and max() modules
# your code here
pass

import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Obtener el valor mínimo de cada columna
min_values = dataset.min()
print("Mínimos:")
print(min_values)
print()

# Obtener el valor máximo de cada columna
max_values = dataset.max()
print("Máximos:")
print(max_values)
# Out:
# Mínimos:
# station_id          40010
# stationname          18th
# date           01/01/2001
# daytype                 A
# rides                   0
# dtype: object
#
# Máximos:
# station_id          41700
# stationname        Wilson
# date           12/31/2022
# daytype                 W
# rides               36323
# dtype: object

# %% [markdown]
# Create a Time Index
#
# So we have all rides from January 1, 2001 to December 31, 2019. Let's do some statistics that group ride statistics by date. First we need to tell Pandas that the date column is in fact a date. So, we convert the column to a proper 'DateTime' type, and then set the index to this column.
#
# This step takes a little bit of time!
#
# The following picture show the desired output
#
# ![image.png](data:image/png;base64,...)

# %%
# hint, use to_datetime() and set_index()  modules
# your code here
pass


import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Convertir la columna de fechas a formato de fecha
dataset['date'] = pd.to_datetime(dataset['date'])

# Establecer la columna de fechas como índice
dataset.set_index('date', inplace=True)

# Realizar operaciones o análisis de datos con el conjunto de datos modificado
# Por ejemplo, puedes acceder a los datos por fechas:
print(dataset.loc['2001-01-01'])
# Out:
#             station_id        stationname daytype  rides
# date
# 2001-01-01       40350        UIC-Halsted       U    273
# 2001-01-01       41130     Halsted-Orange       U    306
# 2001-01-01       40760          Granville       U   1059
# 2001-01-01       40070   Jackson/Dearborn       U    649
# 2001-01-01       40090        Damen-Brown       U    411
# ...                ...                ...     ...    ...
# 2001-01-01       41480      Western-Brown       U    715
# 2001-01-01       41410  Chicago/Milwaukee       U    252
# 2001-01-01       40650     North/Clybourn       U   1156
# 2001-01-01       41230      47th-Dan Ryan       U    787
# 2001-01-01       41240     Addison-O'Hare       U    388
#
# [141 rows x 4 columns]

# %% [markdown]
# Sort the Dataframe by Date

# %%
# hint, sort_values(by='date')
# your code here
pass
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Convertir la columna de fecha a tipo 'DateTime'
dataset['date'] = pd.to_datetime(dataset['date'])

# Ordenar el DataFrame por fecha
dataset.sort_values(by='date', inplace=True)

# Imprimir el DataFrame ordenado por fecha
print(dataset)
# Out:
#          station_id         stationname       date daytype  rides
# 745112        41290             Kimball 2001-01-01       U    869
# 290203        40090         Damen-Brown 2001-01-01       U    411
# 848027        40850             Library 2001-01-01       U    156
# 1072423       40650      North/Clybourn 2001-01-01       U   1156
# 885492        40290        Ashland/63rd 2001-01-01       U    540
# ...             ...                 ...        ...     ...    ...
# 1145461       41660          Lake/State 2022-12-31       A   5491
# 1144004       41000    Cermak-Chinatown 2022-12-31       A   2055
# 1142330       40400               Noyes 2022-12-31       A    121
# 1143911       40970  Cicero-Forest Park 2022-12-31       A    349
# 1145585       41700   Washington/Wabash 2022-12-31       A   2774
#
# [1145586 rows x 5 columns]

# %% [markdown]
# Sanity Checking
#
# Looks good! Now let's have a quick look at data for specific stations:
# 'Garfield-Dan Ryan' and 'Garfield-South Elevated'

# %%
# hint, use filter like, df['stationname']=='Garfield-Dan Ryan']
# your code here
# use the following variable name for your specific stations
Garfield_Dan_Ryan=pd.DataFrame()
pass

import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Filtrar los datos para la estación "Garfield-Dan Ryan"
Garfield_Dan_Ryan = dataset[dataset['stationname'] == 'Garfield-Dan Ryan']

# Mostrar los datos para la estación "Garfield-Dan Ryan"
print(Garfield_Dan_Ryan)
# Out:
#          station_id        stationname        date daytype  rides
# 152           41170  Garfield-Dan Ryan  12/22/2017       W   3040
# 501           41170  Garfield-Dan Ryan  12/05/2017       W   3217
# 645           41170  Garfield-Dan Ryan  12/27/2017       W   2016
# 910           41170  Garfield-Dan Ryan  12/02/2017       A   2624
# 1034          41170  Garfield-Dan Ryan  12/19/2017       W   2958
# ...             ...                ...         ...     ...    ...
# 1144465       41170  Garfield-Dan Ryan  12/27/2022       W    976
# 1144466       41170  Garfield-Dan Ryan  12/28/2022       W    961
# 1144467       41170  Garfield-Dan Ryan  12/29/2022       W    991
# 1144468       41170  Garfield-Dan Ryan  12/30/2022       W   1135
# 1144469       41170  Garfield-Dan Ryan  12/31/2022       A    776
#
# [8005 rows x 5 columns]

# %%
# hint, use filter like this df['stationname']=='Garfield-South Elevated']
# your code here
# use the following variable name for your specific stations
Garfield_South_Elevated=pd.DataFrame()
pass
import pandas as pd

url = 'https://raw.githubusercontent.com/Sinchiguano/chicagoUniversity/main/cta_Ridership.csv'
dataset = pd.read_csv(url)

# Filtrar los datos para la estación "Garfield-South Elevated"
Garfield_South_Elevated = dataset[dataset['stationname'] == 'Garfield-South Elevated']

# Mostrar los datos para la estación "Garfield-South Elevated"
print(Garfield_South_Elevated)
# Out:
#          station_id              stationname        date daytype  rides
# 324           40510  Garfield-South Elevated  12/22/2017       W   1042
# 458           40510  Garfield-South Elevated  12/24/2017       U    431
# 491           40510  Garfield-South Elevated  12/09/2017       A    688
# 890           40510  Garfield-South Elevated  12/17/2017       U    486
# 1176          40510  Garfield-South Elevated  12/31/2017       U    393
# ...             ...                      ...         ...     ...    ...
# 1142605       40510  Garfield-South Elevated  12/27/2022       W    384
# 1142606       40510  Garfield-South Elevated  12/28/2022       W    436
# 1142607       40510  Garfield-South Elevated  12/29/2022       W    448
# 1142608       40510  Garfield-South Elevated  12/30/2022       W    472
# 1142609       40510  Garfield-South Elevated  12/31/2022       A    249
#
# [8035 rows x 5 columns]

# %% [markdown]
# Visualizing Timeseries Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(11, 4)})
# Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)
pass

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(11, 4)})

# Graficar los datos de la estación "Garfield-Dan Ryan"
Garfield_Dan_Ryan['rides'].plot(linewidth=0.5)

# Añadir etiquetas y título al gráfico
plt.xlabel('Fecha')
plt.ylabel('Número de pasajeros')
plt.title('Número de pasajeros en la estación "Garfield-Dan Ryan"')

# Mostrar el gráfico
plt.show()

# %%
sns.set(rc={'figure.figsize':(11, 4)})
# Garfield_South_Elevated['rides'].plot(linewidth=0.5)
pass

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(11, 4)})

# Graficar los datos de la estación "Garfield-South Elevated"
Garfield_South_Elevated['rides'].plot(linewidth=0.5)

# Añadir etiquetas y título al gráfico
plt.xlabel('Fecha')
plt.ylabel('Número de pasajeros')
plt.title('Número de pasajeros en la estación "Garfield-South Elevated"')

# Mostrar el gráfico
plt.show()
